# %% [markdown]
# <h1> NEAT Implementation Practice </h1>
# My Raw NEAT implementation, specifically for the mountaincar environment.

# %% [markdown]
# # Some Notes
# Here are some things about which knobs you can turn in each cell:
# 1. Imports. Don't touch anything there unless you wanna try something out at your own risk.
# 2. Environment Declarations. Change the envName string if you want to test out other environments, but just note that you may need to change some other parameters in the evaluation cell as well if you do so.
# 3. Hyperparameters. Change as you please, but I would recommend sticking to the values from the NEAT paper and/or neatevolve.lua.
# 4. Some functions. I wouldn't touch this.
# 5. Genome Class. I wouldn't touch this, but please feel free to look at the mess I've made. I have recently moved the crossover and delta functions as static methods to this class.
# 8. Evaluation. As mentioned in 2), if you change the environment, then you made need to change the evaluateAction method of the genome or some of the target fitness requirements for episode termination.

# %%
import gym
import numpy as np # might not even need this ?
import random # pseudo-random|
import math
import time # for timing how long it runs for 
import PySimpleGUI as sg
import pickle 
import matplotlib.pyplot as plt

# %%
# %matplotlib qt

# %%
# first define the environment and get the both the action and observation spaces 
envName = 'MountainCar-v0' # just need to change this if you wanna try it in environments
env = gym.make(envName)
plt.title(envName + ' Average Fitness across Generations')
# simple gui stuff
sg.theme = ('DarkAmber')
layout = [  [sg.Text('Trial: '), sg.Text(0, key='TRIAL-NUM', size= (6, 1))],
            [sg.Text('Simulation Info'), sg.Text(''),sg.Text('BestGenome Info')],
            [sg.Text('Generation: '), sg.Text(0, key='GENER-NUM', size = (6,1)), sg.Text('Generation: '), sg.Text(0, key='BEST-GENER-NUM', size = (6,1))],
            [sg.Text('Genome: '), sg.Text(0, key='GENOM-NUM',size = (6,1)), sg.Text('Generation: '), sg.Text(0, key='BEST-GENOM-NUM', size = (6,1))],
            [sg.Text('Species: '), sg.Text(0, key='SPECIES-NUM',size = (6,1)), sg.Text('Species: '), sg.Text(0, key='BEST-SPECIES-NUM',size = (6,1))],
            [sg.Text('Fitness: '), sg.Text(0, key='FITNESS-NUM',size = (6,1)), sg.Text('Fitness: '), sg.Text(0, key='BEST-FITNESS-NUM',size = (6,1))]]



# # print out the observation and action spaces
# print(env.action_space.shape[0]) # number of valid actions we can take 
# print(env.observation_space.shape[0]) # number of "sensors" of the environment that we have (number of inputs)

# NOTE: Need to keep track of the valid values these can take 
# NOTE: Also need to have inputs + 1, with the 1 being the bias (stc?)
# NOTE: changes between Box() and Discrete() depending on environment
outputs = env.action_space.n
inputs = env.observation_space.shape[0] + 1

# %%
# hyperparameters, according to section 4.1 Parameter Settings (changed some parameters for myself)
deltaThreshold = 1.0

c1 = c2 = 2.0
c3 = 0.4
perturbVal = 0.025


numUntilStagnant = 15


genomeMutationChance = 0.25 # neatevolve.lua has this pretty low 
connectionUniformPerturb = 0.9
connectionRandomValue = 1 - connectionUniformPerturb
disableGeneChance = 0.75 
mutateNoCrossoverChance = 0.25
interspeciesMatingRate = 0.01 
smallPopulationNewNodeChance = 0.05
largePopulationNewNodeChance = 0.50 # using these right now 
smallPopulationNewConnectionChance = 0.03
largePopulationNewConnectionChance = 0.30 # using these right now

# %%
# activation functions 
def sigmoid(x):
    return 1/(1+np.exp(-x))

def steepsigmoid(x):
    return 1/(1+np.exp(-4.9*x))

# %%
# genome class 
class Genome:
    # initialize class variables 
    globalInnovationNumber = 1
    def __init__(self, inputs=1, outputs=1):
        self.globalInnovation = 1
        self.nodeGenes = {}
        self.connectGenes = {}
        self.fitness = 0
        self.sharedFitness = 0
        self.species = 0
        self.inputCount = inputs
        self.outputCount = outputs
        self.mutationSuccess = False 
        
    def setGenes(self, nodeGenes, connectGenes):
        self.nodeGenes = nodeGenes.copy()
        self.connectGenes = connectGenes.copy()
        
    @staticmethod
    def copyGenome(genome):
        g = Genome(genome.inputCount, genome.outputCount)
        g.setGenes(genome.nodeGenes, genome.connectGenes)
        return g
    
    @staticmethod
    def resetGlobalInnovationNumber():
        Genome.globalInnovationNumber = 1
        # print('Genome global innovation number reset back to: {}'.format(Genome.globalInnovationNumber))
    
    @staticmethod
    def crossover(genome1, genome2):
        if (genome2.fitness > genome1.fitness):
            temp = genome1
            genome1 = genome2
            genome2 = temp

        g = Genome(genome1.inputCount, genome1.outputCount)
        g.initEmptyGenome()
        g1GenomeList = {}
        for connection in genome1.connectGenes:
            #print(genome1.connectGenes[connection])
            g1GenomeList[genome1.connectGenes[connection][0]]=[connection,genome1.connectGenes[connection][1],genome1.connectGenes[connection][2]]
        g2GenomeList = {}
        for connection in genome2.connectGenes:
            g2GenomeList[genome2.connectGenes[connection][0]]=[connection,genome2.connectGenes[connection][1],genome2.connectGenes[connection][2]] 

        # when crossing over, the genes in both genomes with the same innovation numbers are lined up
        # in composing the offspring, genes are randomly chosen from either parent at matching genes,
        # whereas all excess or disjoint genes are always included from the more fit parent 
        for i in range(max(len(g1GenomeList), len(g2GenomeList))):
            if (i+1 in g1GenomeList and i+1 in g2GenomeList):
                if (random.random() <= 50): # inherit from genome1
                    # print('inherited from parent 1')
                    g.connectGenes[g1GenomeList[i+1][0]] = [i+1, g1GenomeList[i+1][1], g1GenomeList[i+1][2]]
                else: # inherit from genome2 
                    # print('inherited from parent 2')
                    g.connectGenes[g2GenomeList[i+1][0]] = [i+1, g2GenomeList[i+1][1], g2GenomeList[i+1][2]]
                if (g1GenomeList[i+1][2] == False or g1GenomeList[i+1][2] == False):
                    if (random.random() <= disableGeneChance):
                        # print('inherited disabled gene')
                        g.connectGenes[g1GenomeList[i+1][0]][2] = False
                    else:
                        # print('re-enabled inherited gene')
                        g.connectGenes[g1GenomeList[i+1][0]][2] = True
            if (i+1 in g1GenomeList and i+1 not in g2GenomeList):
                g.connectGenes[g1GenomeList[i+1][0]] = [i+1, g1GenomeList[i+1][1], g1GenomeList[i+1][2]]
            # insert the node genes 

        for c in g.connectGenes:
            if c[0] in g1.nodeGenes:
                g.nodeGenes[c[0]] = g1.nodeGenes[c[0]]
            elif c[0] in g2.nodeGenes:
                g.nodeGenes[c[0]] = g2.nodeGenes[c[0]]

            if c[1] in g1.nodeGenes:
                g.nodeGenes[c[1]] = g1.nodeGenes[c[1]]
            elif c[0] in g2.nodeGenes:
                g.nodeGenes[c[1]] = g2.nodeGenes[c[1]]

        g.clearNodeValues()
        return g
    
    @staticmethod
    def delta(genome1, genome2, c1=0.1, c2=0.1, c3=0.1):
        if (not genome1.connectGenes or not genome2.connectGenes):
            return 0
        connectionMismatch = []
        for connection1 in genome1.connectGenes:
            if (connection1 not in genome2.connectGenes):
                connectionMismatch.append(connection1)
        for connection2 in genome2.connectGenes:
            if (connection2 not in genome1.connectGenes):
                connectionMismatch.append(connection2)
        diffsum = 0
        num = 0
        for connection1 in genome1.connectGenes:
            if (connection1 not in connectionMismatch):
                diffsum += abs(genome1.connectGenes[connection1][1] -
                               genome2.connectGenes[connection1][1])
                num += 1
        averageWeightDifference = diffsum / num
        #print(averageWeightDifference)
        N = 0
        if len(genome1.connectGenes) >= len(genome2.connectGenes):
            N = len(genome1.connectGenes)
        else:
            N = len(genome2.connectGenes)
        print(((len(connectionMismatch)*(c1 + c2))/N) + (c3*averageWeightDifference))
        return ((len(connectionMismatch) *
                 (c1 + c2)) / N) + (c3 * averageWeightDifference)
    
    def clearGenome(self):
        self.globalInnovation = 1
        self.nodeGenes.clear()
        self.connectGenes.clear()
        
    def clearNodeValues(self):
        for node in self.nodeGenes:
            self.nodeGenes[node][1] = 0.0
            
    def initEmptyGenome(self):
        self.clearGenome()
        for i in range(self.inputCount):
            self.insertNode('input')
        for i in range(self.outputCount):
            self.insertNode('output')
            
    def resetFitness(self):
        self.fitness = 0
        self.sharedFitness = 0
        
    def initRandomGenome(self):
        self.initEmptyGenome()
        
        # brute force connect each new input node to each output node 
        for node in self.nodeGenes:
            if self.nodeGenes[node][0] == 'input':
                for otherNode in self.nodeGenes:
                    if self.nodeGenes[otherNode][0] == 'output':
                        self.insertConnection(outNode=node, inNode=otherNode, weight=random.uniform(-1, 1))
             
    def insertNode(self, nodeType='input', value = 0.0):
        self.nodeGenes[len(self.nodeGenes)+1]=[nodeType, value]
        
    def insertConnection(self, outNode, inNode, weight = 0.5, isExpressed = True):
        if (outNode in self.nodeGenes) and (inNode in self.nodeGenes): # check if the nodes even exist 
            if ((outNode, inNode) not in self.connectGenes and (inNode, outNode) not in self.connectGenes and self.nodeGenes[inNode][0] != 'input' and outNode != inNode and self.nodeGenes[outNode][0] != 'output'): # check that the connection doesnt already exist
                # also dont allow recurrent connections (only feedforward)
                self.connectGenes[(outNode, inNode)] = [Genome.globalInnovationNumber, weight, isExpressed]
                Genome.globalInnovationNumber += 1
                self.mutationSuccess = True
            else:
                return
                #print('Connection already exists. Did not insert')
        else:
            return
            #print('Could not find node(s). Did not insert.')
            
    def checkConnection(self, outNode, inNode):
        if (outNode in self.nodeGenes) and (inNode in self.nodeGenes):
            if (outNode, inNode) in self.connectGenes:
                return self.connectGenes[(outNode, inNode)][2]
            else:
                print('Could not find the connection')
        else:
            print('Could not find node(s). Did not disable.')
            
    def disableConnection(self, outNode, inNode):
        if (outNode in self.nodeGenes) and (inNode in self.nodeGenes):
            if (outNode, inNode) in self.connectGenes:
                self.connectGenes[(outNode, inNode)][2] = False
            else:
                print('Could not find connection to disable. Did not disable.')
        else: 
            print('Could not find node(s). Did not disable.')
    
    def mutateAddConnection(self, outNode, inNode):
        self.insertConnection(outNode, inNode, random.uniform(-1, 1), True)
            
    def mutateAddRandomConnection(self):
        timesAttemptedToConnected = 0
        self.mutationSuccess = False
        while (not self.mutationSuccess):
            self.mutateAddConnection(random.choice(list(self.nodeGenes)),random.choice(list(self.nodeGenes)))
            timesAttemptedToConnected +=1
            if (timesAttemptedToConnected > 100):
                print('Attempted to connect too many times. probably already full')
                return
        self.mutationSuccess = False
        
    def mutateAddNode(self, outNode, inNode):
        if (outNode in self.nodeGenes) and (inNode in self.nodeGenes):
            if (outNode, inNode) in self.connectGenes:
                self.insertNode('hidden', '0.0')
                # disable old connection'
                self.disableConnection(outNode, inNode)
                self.insertConnection(outNode, len(self.nodeGenes), 1.0, True)
                # get original weight 
                originalWeight = self.connectGenes[(outNode, inNode)][1]
                self.insertConnection(len(self.nodeGenes), inNode, originalWeight, True)
                self.mutationSuccess = True
                print('added hidden node')
            else:
                print('Error! No connection found.')
        else:
            print('Could not find node(s). Did not mutate.')
    
    def mutateAddRandomNode(self):
        if (not self.connectGenes): # need to debug this 
            print('connectGenes is empty. can\'t mutateAddRandomNode')
            return
        self.mutationSuccess = False
        while (not self.mutationSuccess):
            randomTuple = random.choice(list(self.connectGenes))
            self.mutateAddNode(randomTuple[0],randomTuple[1])
        self.mutationSuccess = False
    
    # this is so fucking slow
    def evaluateAction(self, observation):
        # TODO: IMPLEMENT THIS
        if not self.connectGenes:
            return env.action_space.sample()
        else:
            self.clearNodeValues()
            self.nodeGenes[1][1] = 1.0
            for i in range(self.inputCount-1):
                # print('Loading value: {} into node input: {}'.format(observation[i], i+2))
                self.nodeGenes[i+2][1] = observation[i]
            
            for node in self.nodeGenes:
                if self.nodeGenes[node][0] == 'hidden': # for every hidden node
                    x = []
                    w = []
                    for connection in self.connectGenes:
                        if connection[1] == node and self.connectGenes[connection][2] == True: # if inNode == node
                            x.append(self.nodeGenes[connection[0]][1])
                            w.append(self.connectGenes[connection][1])
                    self.nodeGenes[node][1] = steepsigmoid(np.dot(x, w))
                    # print('hidden node #{}\'s value: {}'.format(node, self.nodeGenes[node][1]))
            softmaxsum = 0
            for node in self.nodeGenes:
                if self.nodeGenes[node][0] == 'output':
                    x = []
                    w = []
                    for connection in self.connectGenes:
                        if connection[1] == node and self.connectGenes[connection][2] == True:
                            x.append(self.nodeGenes[connection[0]][1])
                            w.append(self.connectGenes[connection][1])
                    self.nodeGenes[node][1] = np.exp(np.dot(x, w))
                    softmaxsum += np.exp(np.dot(x, w))
                    # print('output node #{}\'s unweighted value: {}'.format(node, self.nodeGenes[node][1]))
            output = []
            for node in self.nodeGenes:
                if self.nodeGenes[node][0] == 'output':
                    output.append(self.nodeGenes[node][1] / softmaxsum)
            # print(output)
            # print('Genome takes action {}'.format(output.index(max(output))))
            return output.index(max(output))
        
    def evaluateActionBox(self, observation):
        # TODO: IMPLEMENT THIS
        if not self.connectGenes:
            return env.action_space.sample()
        else:
            self.clearNodeValues()
            self.nodeGenes[1][1] = 1.0
            for i in range(self.inputCount-1):
                # print('Loading value: {} into node input: {}'.format(observation[i], i+2))
                self.nodeGenes[i+2][1] = observation[i]
            
            for node in self.nodeGenes:
                if self.nodeGenes[node][0] == 'hidden': # for every hidden node
                    x = []
                    w = []
                    for connection in self.connectGenes:
                        if connection[1] == node and self.connectGenes[connection][2] == True: # if inNode == node
                            x.append(self.nodeGenes[connection[0]][1])
                            w.append(self.connectGenes[connection][1])
                    self.nodeGenes[node][1] = steepsigmoid(np.dot(x, w))
                    # print('hidden node #{}\'s value: {}'.format(node, self.nodeGenes[node][1]))
            softmaxsum = 0
            for node in self.nodeGenes:
                if self.nodeGenes[node][0] == 'output':
                    x = []
                    w = []
                    for connection in self.connectGenes:
                        if connection[1] == node and self.connectGenes[connection][2] == True:
                            x.append(self.nodeGenes[connection[0]][1])
                            w.append(self.connectGenes[connection][1])
                    self.nodeGenes[node][1] = np.exp(np.dot(x, w))
                    softmaxsum += np.exp(np.dot(x, w))
                    # print('output node #{}\'s unweighted value: {}'.format(node, self.nodeGenes[node][1]))
            output = []
            for node in self.nodeGenes:
                if self.nodeGenes[node][0] == 'output':
                    output.append(self.nodeGenes[node][1] / softmaxsum)
            # print(output)
            # print('Genome takes action {}'.format(output.index(max(output))))
            return output
    
    def evaluateSharedFitness(self, speciesCount):
        self.sharedFitness = self.fitness / speciesCount
    
    def printNodeGenes(self):
        print(self.nodeGenes)
        
    def printNodeGeneCount(self):
        print(len(self.nodeGenes))
        
    def printConnectGenes(self):
        print(self.connectGenes)
    
    def printConnectGeneCount(self):
        print(len(self.connectGenes))
    
    def printActiveConnectGenes(self):
        for connection in self.connectGenes:
            if (self.connectGenes[connection][2]):
                print(connection, self.connectGenes[connection][1])
        
    def printGlobalInnovation(self):
        print(self.globalInnovation)

# %% [markdown]
# > connection weights mutate as in any NE system, with each connection either perturbed or not at each generation

# %%
max_generations = 50
population_limit = 150
championThresholdCount = 5

inputs = env.observation_space.shape[0] + 1
outputs = env.action_space.n

bestGenomeDictionary = {}

targetPosition = 0.5
maxTestTrials = 100
targetAverageFitness = -110.0

window = sg.Window(envName, layout, finalize=True)
start_time = time.time()

globalEvaluationCounter = 0
solvedCounter = 0

# NOTE: input/output changes depending on environment !

for q in range(maxTestTrials):
    hl, = plt.plot([],[])
    window['TRIAL-NUM'].update(q+1)
    species = {}
    pop = {}
    solved = False
    trialLoopCounter = 0
    bestGenome = None
    highestFitness = float("-inf")
    for generation in range(max_generations):
        generationFitness = 0
        print('Beginning Generation #{}'.format(generation+1))
        window['GENER-NUM'].update(generation+1)
        if (generation == 0 and not pop): # start out with a uniform population of networks with zero hidden networks
            for genome in range(population_limit):
                g = Genome(inputs, outputs)
                Genome.resetGlobalInnovationNumber()
                g.initRandomGenome()
                pop[genome+1] = g

        # in each generation, genomes are sequentially placed into species 

        fitness = []

        for genome in pop:
            print('Beginning evaluation on genome #{}'.format(genome))
            window['GENOM-NUM'].update(genome)
            if (not species):
                print('creating new species:{}'.format(len(species)+1))
                species[len(species)+1] = {'summedSharedFitness': 0.0, 'maxFitness':0.0, 'maxAdjustedFitness': 0.0, 'stagnantCounter' : 0, 'isStagnant':False,'list':[pop[genome]], 'bestGenome': pop[genome]}
                pop[genome].species = len(species)
                print(len(species))
            else:
                for og in species:
                    if (Genome.delta(pop[genome], species[og]['list'][0], c1, c2, c3) < deltaThreshold): # just compare with the first species
                        print('inserting into species#{}'.format(og))
                        species[og]['list'].append(pop[genome])
                        pop[genome].species = og
                        break
                    else:
                        if (og == len(species)):
                            print('creating new species:{}'.format(len(species)+1))
                            species[len(species)+1] ={'summedSharedFitness': 0.0, 'maxFitness':0.0, 'maxAdjustedFitness': 0.0, 'stagnantCounter': 0, 'isStagnant':False,'list':[pop[genome]], 'bestGenome': pop[genome]}
                            pop[genome].species = len(species)
                            print(len(species))
                            break

            window['SPECIES-NUM'].update(pop[genome].species)
            observation = env.reset()
            pop[genome].resetFitness()
            # evalute the genome's performance # SDHJKLSDHLSJKDHLSDHJKLHDSKLDHJ
            t = 0
            trialLoopCounter += 1
            while(True):
                t+=1
                env.render()
                action = pop[genome].evaluateAction(observation)
                observation, reward, done, info = env.step(action)
                pop[genome].fitness += reward
                window['FITNESS-NUM'].update(pop[genome].fitness)
                window.finalize()
                if done:
                    print("Episode finished after {} timesteps".format(t+1))
                    print("Genome fitness: {}".format(pop[genome].fitness))
                    fitness.append(pop[genome].fitness)
                    generationFitness+=pop[genome].fitness
                    if pop[genome].fitness > species[pop[genome].species]['maxFitness']:
                        species[pop[genome].species]['maxFitness'] = pop[genome].fitness
                        species[pop[genome].species]['stagnantCounter'] = 0
                        species[pop[genome].species]['isStagnant'] = False
                    if pop[genome].fitness > highestFitness:
                        bestGenome = pop[genome]
                        highestFitness = pop[genome].fitness
                        # update the window values 
                        window['BEST-GENER-NUM'].update(generation+1)
                        window['BEST-GENOM-NUM'].update(genome)
                        window['BEST-SPECIES-NUM'].update(pop[genome].species)
                        window['BEST-FITNESS-NUM'].update(pop[genome].fitness)
                        window.finalize()
                    if observation[0] >= targetPosition: # changes depending on environment !
                        print('Found an optimal genome. testing it...')
                        testBenchTotalFitness = 0
                        for i in range(maxTestTrials):
                            m = 0
                            pop[genome].resetFitness()
                            observation = env.reset()
                            while(True):
                                m+=1
                                env.render()
                                action = pop[genome].evaluateAction(observation)
                                observation, reward, done, info = env.step(action)
                                pop[genome].fitness += reward
                                window['FITNESS-NUM'].update(pop[genome].fitness)
                                window.finalize()
                                if done:
                                    testBenchTotalFitness+=pop[genome].fitness
                                    print("Genome fitness: {}".format(pop[genome].fitness))
                                    break
                        print('average fitness across 100 trials:{}'.format(testBenchTotalFitness/maxTestTrials))
                        if (testBenchTotalFitness/maxTestTrials >= targetAverageFitness):
                            print('found solution genome')
                            solved = True
                            solvedCounter +=1
                            bestGenomeDictionary[len(bestGenomeDictionary)+1] = pop[genome]
                    break
            if (solved):
                break
        if (solved):
            break
            
        # update the plot of the average fitness across generations 
        hl.set_xdata(np.append(hl.get_xdata(), generation))
        hl.set_ydata(np.append(hl.get_ydata(), generationFitness/population_limit))
        plt.plot(hl.get_xdata(), hl.get_ydata())
        plt.draw()
        print('Number of species at generation {}: {}'.format(generation+1, len(species)))
        # print('highest achieved score in this generation {}'.format(max(fitness)))

        # print(species[1])
        adjustedFitness = []
        totalAdjustedFitness = 0.0
        for genome in pop:
            pop[genome].evaluateSharedFitness(len(species[pop[genome].species]))
            adjustedFitness.append(pop[genome].sharedFitness)
            species[pop[genome].species]['summedSharedFitness'] += pop[genome].sharedFitness
            if pop[genome].sharedFitness > species[pop[genome].species]['maxAdjustedFitness']:
                species[pop[genome].species]['maxAdjustedFitness'] = pop[genome].sharedFitness
                species[pop[genome].species]['bestGenome'] = pop[genome]

        for s in species:
            totalAdjustedFitness += species[s]['summedSharedFitness']
            print('Maximum adjusted fitness in species {}: {}'.format(s, species[s]['maxAdjustedFitness']))
            print('Summed adjusted fitness in species {}: {}'.format(s, species[s]['summedSharedFitness']))

        # print('Total Adjusted Fitness across all species: {}'.format(totalAdjustedFitness))

        newPop = {}

        # the champion of each species with more than 5 networks will be copied into the next generation unchanged
        i = 0
        for s in species:
            if len(species[s]['list']) > championThresholdCount:
                newPop[i+1] = Genome.copyGenome(species[s]['bestGenome'])
                i += 1

        print('New Pop count after copying champions only: {}'.format(len(newPop)))
        print('i\'s value after inserting champions: {}'.format(i))


        # getting the proportion of offspring they are allowed
        totalBreedCount = 0
        for s in species:
            if species[s]['isStagnant']:
                print('species #{} is stagnant'.format(s))
                species[s]['breedAmountAllowed'] = 0
            else:
                species[s]['breedAmountAllowed'] = np.floor((species[s]['summedSharedFitness']/totalAdjustedFitness)*(population_limit-i)).astype(int)
                totalBreedCount += species[s]['breedAmountAllowed']


        leftovers = population_limit - i - totalBreedCount
        print('leftovers:{}'.format(leftovers))
        
        # get rid of the "lowest performing members" of the population
        amountToCull = np.floor(.75*len(pop)).astype(int)
        print('Amount to cull: {}'.format(amountToCull))
        # print(sorted(pop.items(), key=lambda x: x[1].fitness))
        for b in range(amountToCull):
            tempTupleList = sorted(pop.items(), key=lambda x:x[1].fitness, reverse = True)
            tempGenomeKey = tempTupleList.pop()[0]
            tempGenome = pop.pop(tempGenomeKey)
            species[tempGenome.species]['list'].remove(tempGenome)
            print('Removed Genome # {} from species # {}, with a fitness of {}, from the population'.format(tempGenomeKey, tempGenome.species, tempGenome.fitness))


        # now for each species breed !
        for s in species:
            if (len(species[s]['list']) >= 1):
                print('species {} is allowed to have {} offspring'.format(s, species[s]['breedAmountAllowed']))
                for j in range(species[s]['breedAmountAllowed']):
                    print('making offspring #{}'.format(i+1))
                    if (random.random() <= mutateNoCrossoverChance or len(species[s]['list'])==1): # either the genome is a crossover or just the same genome 
                        print('Chose no crossover')
                        g = Genome.copyGenome(random.choice(species[s]['list']))
                    else:
                        print('Chose crossover')
                        g1 = random.choice(species[s]['list'])
                        g2 = random.choice(species[s]['list'])
                        g = Genome.crossover(g1, g2)

                    # add a chance to mutate the connections
                    if (g.connectGenes):
                        if (random.random() <= genomeMutationChance):
                            print('mutation genome connections !')
                            for connection in g.connectGenes:
                                if (random.random() <= connectionUniformPerturb): # uniformly perturb the connection
                                    g.connectGenes[connection][1] += random.uniform(-perturbVal, perturbVal)
                                else:
                                    g.connectGenes[connection][1] = random.uniform(-1.0, 1.0) # set a new value for 


                    # chance to add new connections/nodes
                    if (random.random() <= largePopulationNewNodeChance):
                        print('trying to add new node')
                        g.mutateAddRandomNode()
                    if (random.random() <= largePopulationNewConnectionChance):
                        print('trying to add new connection')
                        g.mutateAddRandomConnection()

                    newPop[i+1] = g
                    i+=1
            else:
                print('could not breed species{}, list is empty !'.format(s))
        # -----------------------------------------------------------------------------------------------------        

        if (leftovers > 0): 
            print('now for the leftovers:')
        for k in range(leftovers): # breeding the leftover genomes that were not calculated through floor
            if (random.random() <= interspeciesMatingRate): # very small chance
                print('interspecies')
                speciesKey1 = random.choice(list(species))
                speciesKey2 = random.choice(list(species))
                if (len(species[speciesKey1]['list']) < 1 or len(species[speciesKey2]['list']) < 1):
                    print('either species does not have enough to breed. skipping.')
                    k -= 1
                    continue
                g1 = random.choice(species[speciesKey1]['list'])
                g2 = random.choice(species[speciesKey2]['list'])
                g = Genome.crossover(g1, g2)
                if (g.connectGenes):
                    if (random.random() <= genomeMutationChance):
                        print('mutation genome connections !')
                        for connection in g.connectGenes:
                            if (random.random() <= connectionUniformPerturb): # uniformly perturb the connection
                                g.connectGenes[connection][1] += random.uniform(-perturbVal, perturbVal)
                            else:
                                g.connectGenes[connection][1] = random.uniform(-1.0, 1.0) # set a new value for 


                # chance to add new connections/nodes
                if (random.random() <= largePopulationNewNodeChance):
                    print('trying to add new node')
                    g.mutateAddRandomNode()
                if (random.random() <= largePopulationNewConnectionChance):
                    print('trying to add new connection')
                    g.mutateAddRandomConnection()


                newPop[i+1] = g
                i+=1
            else: # else just find a random species and mate from there 
                print('random species mating')
                speciesKey = random.choice(list(species))
                if (len(species[speciesKey]['list']) < 1):
                    print('species does not have enough to breed. skipping.')
                    k -= 1
                    continue
                if (random.random() <= mutateNoCrossoverChance or len(species[speciesKey]['list']) < 2): # either the genome is a crossover or just the same genome 
                    print('Chose no crossover')
                    g = Genome.copyGenome(random.choice(species[speciesKey]['list']))
                else:
                    print('Chose crossover')
                    g1 = random.choice(species[speciesKey]['list'])
                    g2 = random.choice(species[speciesKey]['list'])
                    g = Genome.crossover(g1, g2)

                # add a chance to mutate the connections
                if (g.connectGenes):
                    if (random.random() <= genomeMutationChance):
                        print('mutation genome connections !')
                        for connection in g.connectGenes:
                            if (random.random() <= connectionUniformPerturb): # uniformly perturb the connection
                                g.connectGenes[connection][1] += random.uniform(-perturbVal, perturbVal)
                            else:
                                g.connectGenes[connection][1] = random.uniform(-1.0, 1.0) # set a new value for 


                # chance to add new connections/nodes
                if (random.random() <= largePopulationNewNodeChance):
                    print('trying to add new node')
                    g.mutateAddRandomNode()
                if (random.random() <= largePopulationNewConnectionChance):
                    print('trying to add new connection')
                    g.mutateAddRandomConnection()


                newPop[i+1] = g
                i+=1


        print('Final value of i: {}'.format(i))

        # ------------------------------------------------------------------------------------------

        # each existing species is represented by a random genome inside the species from the previous generation 
        if (generation >= 0):
            for s in species:
                species[s] = {'summedSharedFitness': 0.0, 'maxFitness': 0.0, 'maxAdjustedFitness': 0.0, 'stagnantCounter': species[s]['stagnantCounter']+1, 'isStagnant': False, 'list' : [random.choice(species[s]['list'])]}
                species[s]['bestGenome'] = species[s]['list'][0]
                if species[s]['stagnantCounter'] >= numUntilStagnant:  # if the maximum fitness of a species did not improve in 15 generations, the networks in the stagnant species were not allowed to reproduce 
                    species[s]['isStagnant'] = True




        pop.clear()
        pop = newPop.copy()


    print('Total number of evaluations for this trial: {}'.format(trialLoopCounter))
    globalEvaluationCounter += trialLoopCounter 

print("--- %s seconds ---" % (time.time() - start_time))
print('{} solved out of {} trials'.format(solvedCounter, maxTestTrials))    
print('Total Number of evaluations overall {}'.format(globalEvaluationCounter))
print('Average evaluation count per trial: {}'.format(globalEvaluationCounter / maxTestTrials))
window.close()
env.close()
# saving contents of population into pickle when it is finished 
with open('data/pop.dictionary', 'wb') as config_dictionary_file:
    pickle.dump(pop, config_dictionary_file)
    
with open('data/bestGenome_'+envName+'.dictionary', 'wb') as dictionary_file:
    pickle.dump(bestGenomeDictionary, dictionary_file)
# Out:
# Beginning Generation #1
# Beginning evaluation on genome #1
# creating new species:1
# 1
# Episode finished after 201 timesteps
# Genome fitness: -200.0
# Beginning evaluation on genome #2
# 0.2243839412375649
# inserting into species#1
# Episode finished after 201 timesteps
# Genome fitness: -200.0
# Beginning evaluation on genome #3
# 0.1433186338267129
# inserting into species#1
# Episode finished after 201 timesteps
# Genome fitness: -200.0
# Beginning evaluation on genome #4
# 0.24881349872520744
# inserting into species#1
# Episode finished after 201 timesteps
# Genome fitness: -200.0
# Beginning evaluation on genome #5
# 0.16629276197539686
# inserting into species#1
# Episode finished after 201 timesteps
# Genome fitness: -200.0
# Beginning evaluation on genome #6
# 0.2964565385816928
# inserting into species#1
# Episode finished after 201 timesteps
# Genome fitness: -200.0
# Beginning evaluation on genome #7
# 0.17470989106679097
# inserting into species#1
# Episode finished after 201 timesteps
# Genome fitness: -200.0
# Beginning evaluation on genome #8
# 0.21914173656781327
# inserting into species#1
# Episode finished after 201 timesteps
# Genome fitness: -200.0
# Beginning evaluation on genome #9
# 0.24871377048281196
# inserting into species#1
# Episode finished after 201 timesteps
# Genome fitness: -200.0
# Beginning evaluation on genome #10
# 0.22684110652341452
# inserting into species#1
# Episode finished after 201 timesteps
# Genome fitness: -200.0
# Beginning evaluation on genome #11
# 0.2335545809123985
# inserting into species#1
# Episode finished after 201 timesteps
# Genome fitness: -200.0
# Beginning evaluation on genome #12
# 0.22768375410125624
# inserting into species#1
# Episode finished after 201 timesteps
# Genome fitness: -200.0
# Beginning evaluation on genome #13
# 0.16698477957613833
# inserting into species#1
# Episode finished after 201 timesteps
# Genome fitness: -200.0
# Beginning evaluation on genome #14
# 0.30261404115209023
# inserting into species#1
# Episode finished after 201 timesteps
# Genome fitness: -200.0
# Beginning evaluation on genome #15
# 0.22094408724984604
# inserting into species#1
# Episode finished after 201 timesteps
# Genome fitness: -200.0
# Beginning evaluation on genome #16
# 0.2765997181105808
# inserting into species#1
# Episode finished after 201 timesteps
# Genome fitness: -200.0
# Beginning evaluation on genome #17
# 0.18102147356346648
# inserting into species#1
# Episode finished after 201 timesteps
# Genome fitness: -200.0
# Beginning evaluation on genome #18
# 0.2754769206814471
# inserting into species#1
# Episode finished after 201 timesteps
# Genome fitness: -200.0
# Beginning evaluation on genome #19
# 0.2745057343290995
# inserting into species#1
# Episode finished after 201 timesteps
# Genome fitness: -200.0
# Beginning evaluation on genome #20
# 0.2558480968599234
# inserting into species#1
# Episode finished after 201 timesteps
# Genome fitness: -200.0
# Beginning evaluation on genome #21
# 0.33871678661390514
# inserting into species#1
# Episode finished after 201 timesteps
# Genome fitness: -200.0
# Beginning evaluation on genome #22
# 0.30427524678530854
# inserting into species#1
# Episode finished after 201 timesteps
# Genome fitness: -200.0
# Beginning evaluation on genome #23
# 0.1684181056456865
# inserting into species#1
# Episode finished after 201 timesteps
# Genome fitness: -200.0
# Beginning evaluation on genome #24
# 0.1028782670716084
# inserting into species#1
# Episode finished after 201 timesteps
# Genome fitness: -200.0
# Beginning evaluation on genome #25
# 0.22285130214774457
# inserting into species#1
# Episode finished after 201 timesteps
# Genome fitness: -200.0
# Beginning evaluation on genome #26
# 0.1696052513252455
# inserting into species#1
# Episode finished after 201 timesteps
# Genome fitness: -200.0
# Beginning evaluation on genome #27
# 0.2690100258472157
# inserting into species#1
# Episode finished after 201 timesteps
# Genome fitness: -200.0
# Beginning evaluation on genome #28
# 0.2710535433299199
# inserting into species#1
# Episode finished after 201 timesteps
# Genome fitness: -200.0
# Beginning evaluation on genome #29
# 0.3154725454166363
# inserting into species#1
# Episode finished after 201 timesteps
# Genome fitness: -200.0
# Beginning evaluation on genome #30
# 0.31604600287947515
# inserting into species#1
# Episode finished after 201 timesteps
# Genome fitness: -200.0
# Beginning evaluation on genome #31
# 0.23007363451052948
# inserting into species#1
# Episode finished after 201 timesteps
# Genome fitness: -200.0
# Beginning evaluation on genome #32
# 0.24072507770563445
# inserting into species#1
# Episode finished after 201 timesteps
# Genome fitness: -200.0
# Beginning evaluation on genome #33
# 0.1433399753240918
# inserting into species#1
# Episode finished after 201 timesteps
# Genome fitness: -200.0
# Beginning evaluation on genome #34
# 0.22750876780761772
# inserting into species#1
# Episode finished after 201 timesteps
# Genome fitness: -200.0
# Beginning evaluation on genome #35
# 0.24991007595463685
# inserting into species#1
# Episode finished after 201 timesteps
# Genome fitness: -200.0
# Beginning evaluation on genome #36
# 0.2225859441818514
# inserting into species#1
# Episode finished after 201 timesteps
# Genome fitness: -200.0
# Beginning evaluation on genome #37
# 0.25057188959593224
# inserting into species#1
# Episode finished after 201 timesteps
# Genome fitness: -200.0
# Beginning evaluation on genome #38
# 0.22813836153400235
# inserting into species#1
# Episode finished after 201 timesteps
# Genome fitness: -200.0
# Beginning evaluation on genome #39
# 0.15754942016079562
# inserting into species#1
# Episode finished after 201 timesteps
# Genome fitness: -200.0
# Beginning evaluation on genome #40
# 0.2801238426157699
# inserting into species#1
# Episode finished after 201 timesteps
# Genome fitness: -200.0
# Beginning evaluation on genome #41
# 0.27085687393077534
# inserting into species#1
# Episode finished after 201 timesteps
# Genome fitness: -200.0
# Beginning evaluation on genome #42
# 0.2744590756680154
# inserting into species#1
# Episode finished after 201 timesteps
# Genome fitness: -200.0
# Beginning evaluation on genome #43
# 0.2647994364180486
# inserting into species#1
# Episode finished after 201 timesteps
# Genome fitness: -200.0
# Beginning evaluation on genome #44
# 0.24143199395650414
# inserting into species#1
# Episode finished after 201 timesteps
# Genome fitness: -200.0
# Beginning evaluation on genome #45
# 0.25186580602641734
# inserting into species#1
# Episode finished after 201 timesteps
# Genome fitness: -200.0
# Beginning evaluation on genome #46
# 0.18907707729671452
# inserting into species#1
# Episode finished after 201 timesteps
# Genome fitness: -200.0
# Beginning evaluation on genome #47
# 0.1677118914115403
# inserting into species#1
# Episode finished after 201 timesteps
# Genome fitness: -200.0
# Beginning evaluation on genome #48
# 0.3104242573881522
# inserting into species#1
# Episode finished after 201 timesteps
# Genome fitness: -200.0
# Beginning evaluation on genome #49
# 0.23080825857830192
# inserting into species#1
# Episode finished after 201 timesteps
# Genome fitness: -200.0
# Beginning evaluation on genome #50
# 0.208748279427927
# inserting into species#1
# Episode finished after 201 timesteps
# Genome fitness: -200.0
# Beginning evaluation on genome #51
# 0.19025796985464627
# inserting into species#1
# Episode finished after 201 timesteps
# Genome fitness: -200.0
# Beginning evaluation on genome #52
# 0.34946526229343
# inserting into species#1
# Episode finished after 201 timesteps
# Genome fitness: -200.0
# Beginning evaluation on genome #53
# 0.2067436523112178
# inserting into species#1
# Episode finished after 201 timesteps
# Genome fitness: -200.0
# Beginning evaluation on genome #54
# 0.29418202028569684
# inserting into species#1
# Episode finished after 201 timesteps
# Genome fitness: -200.0
# Beginning evaluation on genome #55
# 0.3158334288735755
# inserting into species#1
# Episode finished after 201 timesteps
# Genome fitness: -200.0
# Beginning evaluation on genome #56
# 0.30046561404633687
# inserting into species#1
# Episode finished after 201 timesteps
# Genome fitness: -200.0
# Beginning evaluation on genome #57
# 0.2189071168717344
# inserting into species#1
# Episode finished after 201 timesteps
# Genome fitness: -200.0
# Beginning evaluation on genome #58
# 0.20858633025398401
# inserting into species#1
# Episode finished after 201 timesteps
# Genome fitness: -200.0
# Beginning evaluation on genome #59
# 0.3058586486101122
# inserting into species#1
# Episode finished after 201 timesteps
# Genome fitness: -200.0
# Beginning evaluation on genome #60
# 0.2394060709369752
# inserting into species#1
# Episode finished after 201 timesteps
# Genome fitness: -200.0
# Beginning evaluation on genome #61
# 0.21668383676047234
# inserting into species#1
# Episode finished after 201 timesteps
# Genome fitness: -200.0
# Beginning evaluation on genome #62
# 0.29103236832001766
# inserting into species#1
# Episode finished after 201 timesteps
# Genome fitness: -200.0
# Beginning evaluation on genome #63
# 0.19670361447489848
# inserting into species#1
# Episode finished after 201 timesteps
# Genome fitness: -200.0
# Beginning evaluation on genome #64
# 0.22269560282134881
# inserting into species#1
# Episode finished after 201 timesteps
# Genome fitness: -200.0
# Beginning evaluation on genome #65
# 0.31188155185627536
# inserting into species#1
# Episode finished after 201 timesteps
# Genome fitness: -200.0
# Beginning evaluation on genome #66
# 0.2085477615720393
# inserting into species#1
# Episode finished after 201 timesteps
# Genome fitness: -200.0
# Beginning evaluation on genome #67
# 0.2704989596829637
# inserting into species#1
# Episode finished after 201 timesteps
# Genome fitness: -200.0
# Beginning evaluation on genome #68
# 0.2501186077910073
# inserting into species#1
# Episode finished after 201 timesteps
# Genome fitness: -200.0
# Beginning evaluation on genome #69
# 0.23943940370831812
# inserting into species#1
# Episode finished after 201 timesteps
# Genome fitness: -200.0
# Beginning evaluation on genome #70
# 0.25911354646404366
# inserting into species#1
# Episode finished after 201 timesteps
# Genome fitness: -200.0
# Beginning evaluation on genome #71
# 0.28484138599179637
# inserting into species#1
# Episode finished after 201 timesteps
# Genome fitness: -200.0
# Beginning evaluation on genome #72
# 0.19851510644071224
# inserting into species#1
# Episode finished after 201 timesteps
# Genome fitness: -200.0
# Beginning evaluation on genome #73
# 0.2674129251812799
# inserting into species#1
# Episode finished after 201 timesteps
# Genome fitness: -200.0
# Beginning evaluation on genome #74
# 0.2605802007832873
# inserting into species#1
# Episode finished after 201 timesteps
# Genome fitness: -200.0
# Beginning evaluation on genome #75
# 0.16492234734726396
# inserting into species#1
# Episode finished after 201 timesteps
# Genome fitness: -200.0
# Beginning evaluation on genome #76
# 0.28384292234986963
# inserting into species#1
# Episode finished after 201 timesteps
# Genome fitness: -200.0
# Beginning evaluation on genome #77
# 0.2528323246337587
# inserting into species#1
# Episode finished after 201 timesteps
# Genome fitness: -200.0
# Beginning evaluation on genome #78
# 0.2509472827104517
# inserting into species#1
# Episode finished after 201 timesteps
# Genome fitness: -200.0
# Beginning evaluation on genome #79
# 0.2307432084837689
# inserting into species#1
# Episode finished after 201 timesteps
# Genome fitness: -200.0
# Beginning evaluation on genome #80
# 0.28053639092966287
# inserting into species#1
# Episode finished after 201 timesteps
# Genome fitness: -200.0
# Beginning evaluation on genome #81
# 0.18421510551076747
# inserting into species#1
# Episode finished after 201 timesteps
# Genome fitness: -200.0
# Beginning evaluation on genome #82
# 0.24817365271995367
# inserting into species#1
# Episode finished after 201 timesteps
# Genome fitness: -200.0
# Beginning evaluation on genome #83
# 0.31102348834959725
# inserting into species#1
# Episode finished after 201 timesteps
# Genome fitness: -200.0
# Beginning evaluation on genome #84
# 0.2289599202090046
# inserting into species#1
# Episode finished after 201 timesteps
# Genome fitness: -200.0
# Beginning evaluation on genome #85
# 0.3204806629048831
# inserting into species#1
# Episode finished after 201 timesteps
# Genome fitness: -200.0
# Beginning evaluation on genome #86
# 0.26394771441486686
# inserting into species#1
# Episode finished after 201 timesteps
# Genome fitness: -200.0
# Beginning evaluation on genome #87
# 0.2316142500733007
# inserting into species#1
# Episode finished after 201 timesteps
# Genome fitness: -200.0
# Beginning evaluation on genome #88
# 0.22203344325108515
# inserting into species#1
# Episode finished after 201 timesteps
# Genome fitness: -200.0
# Beginning evaluation on genome #89
# 0.21022898725078565
# inserting into species#1
# Episode finished after 201 timesteps
# Genome fitness: -200.0
# Beginning evaluation on genome #90
# 0.293430053107149
# inserting into species#1
# Episode finished after 201 timesteps
# Genome fitness: -200.0
# Beginning evaluation on genome #91
# 0.3195752058603927
# inserting into species#1
# Episode finished after 201 timesteps
# Genome fitness: -200.0
# Beginning evaluation on genome #92
# 0.2149382185816746
# inserting into species#1
# Episode finished after 201 timesteps
# Genome fitness: -200.0
# Beginning evaluation on genome #93
# 0.24012383846471327
# inserting into species#1
# Episode finished after 201 timesteps
# Genome fitness: -200.0
# Beginning evaluation on genome #94
# 0.30075314624138183
# inserting into species#1
# Episode finished after 201 timesteps
# Genome fitness: -200.0
# Beginning evaluation on genome #95
# 0.1343784443276024
# inserting into species#1
# Episode finished after 201 timesteps
# Genome fitness: -200.0
# Beginning evaluation on genome #96
# 0.2342173976571169
# inserting into species#1
# Episode finished after 201 timesteps
# Genome fitness: -200.0
# Beginning evaluation on genome #97
# 0.2583503700085057
# inserting into species#1
# Episode finished after 201 timesteps
# Genome fitness: -200.0
# Beginning evaluation on genome #98
# 0.17247377507864875
# inserting into species#1
# Episode finished after 201 timesteps
# Genome fitness: -200.0
# Beginning evaluation on genome #99
# 0.2339595926695441
# inserting into species#1
# Episode finished after 201 timesteps
# Genome fitness: -200.0
# Beginning evaluation on genome #100
# 0.24388210445043598
# inserting into species#1
# Episode finished after 201 timesteps
# Genome fitness: -200.0
# Beginning evaluation on genome #101
# 0.24836093485347044
# inserting into species#1
# Episode finished after 201 timesteps
# Genome fitness: -200.0
# Beginning evaluation on genome #102
# 0.19437273687780576
# inserting into species#1
# Episode finished after 201 timesteps
# Genome fitness: -200.0
# Beginning evaluation on genome #103
# 0.2820109120164497
# inserting into species#1
# Episode finished after 201 timesteps
# Genome fitness: -200.0
# Beginning evaluation on genome #104
# 0.2536117952869147
# inserting into species#1
# Episode finished after 201 timesteps
# Genome fitness: -200.0
# Beginning evaluation on genome #105
# 0.19578291296293904
# inserting into species#1
# Episode finished after 201 timesteps
# Genome fitness: -200.0
# Beginning evaluation on genome #106
# 0.16235256154523958
# inserting into species#1
# Episode finished after 201 timesteps
# Genome fitness: -200.0
# Beginning evaluation on genome #107
# 0.16885097752030986
# inserting into species#1
# Episode finished after 201 timesteps
# Genome fitness: -200.0
# Beginning evaluation on genome #108
# 0.18531519349843495
# inserting into species#1
# Episode finished after 201 timesteps
# Genome fitness: -200.0
# Beginning evaluation on genome #109
# 0.21584497111200635
# inserting into species#1
# Episode finished after 201 timesteps
# Genome fitness: -200.0
# Beginning evaluation on genome #110
# 0.22305704437464013
# inserting into species#1
# Episode finished after 201 timesteps
# Genome fitness: -200.0
# Beginning evaluation on genome #111
# 0.23088154019282048
# inserting into species#1
# Episode finished after 201 timesteps
# Genome fitness: -200.0
# Beginning evaluation on genome #112
# 0.17516493427098265
# inserting into species#1
# Episode finished after 201 timesteps
# Genome fitness: -200.0
# Beginning evaluation on genome #113
# 0.32232507368362723
# inserting into species#1
# Episode finished after 201 timesteps
# Genome fitness: -200.0
# Beginning evaluation on genome #114
# 0.24901902799626013
# inserting into species#1
# Episode finished after 201 timesteps
# Genome fitness: -200.0
# Beginning evaluation on genome #115
# 0.32434047376553554
# inserting into species#1
# Episode finished after 201 timesteps
# Genome fitness: -200.0
# Beginning evaluation on genome #116
# 0.291203029247132
# inserting into species#1
# Episode finished after 201 timesteps
# Genome fitness: -200.0
# Beginning evaluation on genome #117
# 0.2085353401028725
# inserting into species#1
# Episode finished after 201 timesteps
# Genome fitness: -200.0
# Beginning evaluation on genome #118
# 0.20769135263194236
# inserting into species#1
# Episode finished after 201 timesteps
# Genome fitness: -200.0
# Beginning evaluation on genome #119
# 0.159999158372598
# inserting into species#1
# Episode finished after 201 timesteps
# Genome fitness: -200.0
# Beginning evaluation on genome #120
# 0.23925080723831088
# inserting into species#1
# Episode finished after 201 timesteps
# Genome fitness: -200.0
# Beginning evaluation on genome #121
# 0.28120949972049275
# inserting into species#1
# Episode finished after 201 timesteps
# Genome fitness: -200.0
# Beginning evaluation on genome #122
# 0.1744662991913099
# inserting into species#1
# Episode finished after 201 timesteps
# Genome fitness: -200.0
# Beginning evaluation on genome #123
# 0.24411979229937333
# inserting into species#1
# Episode finished after 201 timesteps
# Genome fitness: -200.0
# Beginning evaluation on genome #124
# 0.3078992263726333
# inserting into species#1
# Episode finished after 201 timesteps
# Genome fitness: -200.0
# Beginning evaluation on genome #125
# 0.2175658217857179
# inserting into species#1
# Episode finished after 201 timesteps
# Genome fitness: -200.0
# Beginning evaluation on genome #126
# 0.3126655153829657
# inserting into species#1
# Episode finished after 201 timesteps
# Genome fitness: -200.0
# Beginning evaluation on genome #127
# 0.27035817380809507
# inserting into species#1
# Episode finished after 201 timesteps
# Genome fitness: -200.0
# Beginning evaluation on genome #128
# 0.40171568257579476
# inserting into species#1
# Episode finished after 201 timesteps
# Genome fitness: -200.0
# Beginning evaluation on genome #129
# 0.2835039548822295
# inserting into species#1
# Episode finished after 201 timesteps
# Genome fitness: -200.0
# Beginning evaluation on genome #130
# 0.21364209782761365
# inserting into species#1
# Episode finished after 201 timesteps
# Genome fitness: -200.0
# Beginning evaluation on genome #131
# 0.24546155688697038
# inserting into species#1
# Episode finished after 201 timesteps
# Genome fitness: -200.0
# Beginning evaluation on genome #132
# 0.3441208791476616
# inserting into species#1
# Episode finished after 201 timesteps
# Genome fitness: -200.0
# Beginning evaluation on genome #133
# 0.23285734031314537
# inserting into species#1
# Episode finished after 201 timesteps
# Genome fitness: -200.0
# Beginning evaluation on genome #134
# 0.2422606986532419
# inserting into species#1
# Episode finished after 201 timesteps
# Genome fitness: -200.0
# Beginning evaluation on genome #135
# 0.27234768910670126
# inserting into species#1
# Episode finished after 201 timesteps
# Genome fitness: -200.0
# Beginning evaluation on genome #136
# 0.20402627798590656
# inserting into species#1
# Episode finished after 201 timesteps
# Genome fitness: -200.0
# Beginning evaluation on genome #137
# 0.29366034744649444
# inserting into species#1
# Episode finished after 201 timesteps
# Genome fitness: -200.0
# Beginning evaluation on genome #138
# 0.31861023238770664
# inserting into species#1
# Episode finished after 201 timesteps
# Genome fitness: -200.0
# Beginning evaluation on genome #139
# 0.26285116367426886
# inserting into species#1
# Episode finished after 201 timesteps
# Genome fitness: -200.0
# Beginning evaluation on genome #140
# 0.235829617763489
# inserting into species#1
# Episode finished after 201 timesteps
# Genome fitness: -200.0
# Beginning evaluation on genome #141
# 0.35100873171478564
# inserting into species#1
# Episode finished after 201 timesteps
# Genome fitness: -200.0
# Beginning evaluation on genome #142
# 0.27523486925714713
# inserting into species#1
# Episode finished after 201 timesteps
# Genome fitness: -200.0
# Beginning evaluation on genome #143
# 0.19389003120564194
# inserting into species#1
# Episode finished after 201 timesteps
# Genome fitness: -200.0
# Beginning evaluation on genome #144
# 0.19566408667769514
# inserting into species#1
# Episode finished after 201 timesteps
# Genome fitness: -200.0
# Beginning evaluation on genome #145
# 0.15944052802676928
# inserting into species#1
# Episode finished after 201 timesteps
# Genome fitness: -200.0
# Beginning evaluation on genome #146
# 0.22071756864433467
# inserting into species#1
# Episode finished after 201 timesteps
# Genome fitness: -200.0
# Beginning evaluation on genome #147
# 0.23614065919304564
# inserting into species#1
# Episode finished after 201 timesteps
# Genome fitness: -200.0
# Beginning evaluation on genome #148
# 0.27612721168273213
# inserting into species#1
# Episode finished after 201 timesteps
# Genome fitness: -200.0
# Beginning evaluation on genome #149
# 0.2821393126686775
# inserting into species#1
# Episode finished after 201 timesteps
# Genome fitness: -200.0
# Beginning evaluation on genome #150
# 0.3185495315733162
# inserting into species#1
# Episode finished after 201 timesteps
# Genome fitness: -200.0
# Number of species at generation 1: 1
# Maximum adjusted fitness in species 1: 0.0
# Summed adjusted fitness in species 1: -4285.714285714279
# New Pop count after copying champions only: 1
# i's value after inserting champions: 1
# leftovers:0
# Amount to cull: 112
# Removed Genome # 150 from species # 1, with a fitness of -200.0, from the population
# Removed Genome # 149 from species # 1, with a fitness of -200.0, from the population
# Removed Genome # 148 from species # 1, with a fitness of -200.0, from the population
# Removed Genome # 147 from species # 1, with a fitness of -200.0, from the population
# Removed Genome # 146 from species # 1, with a fitness of -200.0, from the population
# Removed Genome # 145 from species # 1, with a fitness of -200.0, from the population
# Removed Genome # 144 from species # 1, with a fitness of -200.0, from the population
# Removed Genome # 143 from species # 1, with a fitness of -200.0, from the population
# Removed Genome # 142 from species # 1, with a fitness of -200.0, from the population
# Removed Genome # 141 from species # 1, with a fitness of -200.0, from the population
# Removed Genome # 140 from species # 1, with a fitness of -200.0, from the population
# Removed Genome # 139 from species # 1, with a fitness of -200.0, from the population
# Removed Genome # 138 from species # 1, with a fitness of -200.0, from the population
# Removed Genome # 137 from species # 1, with a fitness of -200.0, from the population
# Removed Genome # 136 from species # 1, with a fitness of -200.0, from the population
# Removed Genome # 135 from species # 1, with a fitness of -200.0, from the population
# Removed Genome # 134 from species # 1, with a fitness of -200.0, from the population
# Removed Genome # 133 from species # 1, with a fitness of -200.0, from the population
# Removed Genome # 132 from species # 1, with a fitness of -200.0, from the population
# Removed Genome # 131 from species # 1, with a fitness of -200.0, from the population
# Removed Genome # 130 from species # 1, with a fitness of -200.0, from the population
# Removed Genome # 129 from species # 1, with a fitness of -200.0, from the population
# Removed Genome # 128 from species # 1, with a fitness of -200.0, from the population
# Removed Genome # 127 from species # 1, with a fitness of -200.0, from the population
# Removed Genome # 126 from species # 1, with a fitness of -200.0, from the population
# Removed Genome # 125 from species # 1, with a fitness of -200.0, from the population
# Removed Genome # 124 from species # 1, with a fitness of -200.0, from the population
# Removed Genome # 123 from species # 1, with a fitness of -200.0, from the population
# Removed Genome # 122 from species # 1, with a fitness of -200.0, from the population
# Removed Genome # 121 from species # 1, with a fitness of -200.0, from the population
# Removed Genome # 120 from species # 1, with a fitness of -200.0, from the population
# Removed Genome # 119 from species # 1, with a fitness of -200.0, from the population
# Removed Genome # 118 from species # 1, with a fitness of -200.0, from the population
# Removed Genome # 117 from species # 1, with a fitness of -200.0, from the population
# Removed Genome # 116 from species # 1, with a fitness of -200.0, from the population
# Removed Genome # 115 from species # 1, with a fitness of -200.0, from the population
# Removed Genome # 114 from species # 1, with a fitness of -200.0, from the population
# Removed Genome # 113 from species # 1, with a fitness of -200.0, from the population
# Removed Genome # 112 from species # 1, with a fitness of -200.0, from the population
# Removed Genome # 111 from species # 1, with a fitness of -200.0, from the population
# Removed Genome # 110 from species # 1, with a fitness of -200.0, from the population
# Removed Genome # 109 from species # 1, with a fitness of -200.0, from the population
# Removed Genome # 108 from species # 1, with a fitness of -200.0, from the population
# Removed Genome # 107 from species # 1, with a fitness of -200.0, from the population
# Removed Genome # 106 from species # 1, with a fitness of -200.0, from the population
# Removed Genome # 105 from species # 1, with a fitness of -200.0, from the population
# Removed Genome # 104 from species # 1, with a fitness of -200.0, from the population
# Removed Genome # 103 from species # 1, with a fitness of -200.0, from the population
# Removed Genome # 102 from species # 1, with a fitness of -200.0, from the population
# Removed Genome # 101 from species # 1, with a fitness of -200.0, from the population
# Removed Genome # 100 from species # 1, with a fitness of -200.0, from the population
# Removed Genome # 99 from species # 1, with a fitness of -200.0, from the population
# Removed Genome # 98 from species # 1, with a fitness of -200.0, from the population
# Removed Genome # 97 from species # 1, with a fitness of -200.0, from the population
# Removed Genome # 96 from species # 1, with a fitness of -200.0, from the population
# Removed Genome # 95 from species # 1, with a fitness of -200.0, from the population
# Removed Genome # 94 from species # 1, with a fitness of -200.0, from the population
# Removed Genome # 93 from species # 1, with a fitness of -200.0, from the population
# Removed Genome # 92 from species # 1, with a fitness of -200.0, from the population
# Removed Genome # 91 from species # 1, with a fitness of -200.0, from the population
# Removed Genome # 90 from species # 1, with a fitness of -200.0, from the population
# Removed Genome # 89 from species # 1, with a fitness of -200.0, from the population
# Removed Genome # 88 from species # 1, with a fitness of -200.0, from the population
# Removed Genome # 87 from species # 1, with a fitness of -200.0, from the population
# Removed Genome # 86 from species # 1, with a fitness of -200.0, from the population
# Removed Genome # 85 from species # 1, with a fitness of -200.0, from the population
# Removed Genome # 84 from species # 1, with a fitness of -200.0, from the population
# Removed Genome # 83 from species # 1, with a fitness of -200.0, from the population
# Removed Genome # 82 from species # 1, with a fitness of -200.0, from the population
# Removed Genome # 81 from species # 1, with a fitness of -200.0, from the population
# Removed Genome # 80 from species # 1, with a fitness of -200.0, from the population
# Removed Genome # 79 from species # 1, with a fitness of -200.0, from the population
# Removed Genome # 78 from species # 1, with a fitness of -200.0, from the population
# Removed Genome # 77 from species # 1, with a fitness of -200.0, from the population
# Removed Genome # 76 from species # 1, with a fitness of -200.0, from the population
# Removed Genome # 75 from species # 1, with a fitness of -200.0, from the population
# Removed Genome # 74 from species # 1, with a fitness of -200.0, from the population
# Removed Genome # 73 from species # 1, with a fitness of -200.0, from the population
# Removed Genome # 72 from species # 1, with a fitness of -200.0, from the population
# Removed Genome # 71 from species # 1, with a fitness of -200.0, from the population
# Removed Genome # 70 from species # 1, with a fitness of -200.0, from the population
# Removed Genome # 69 from species # 1, with a fitness of -200.0, from the population
# Removed Genome # 68 from species # 1, with a fitness of -200.0, from the population
# Removed Genome # 67 from species # 1, with a fitness of -200.0, from the population
# Removed Genome # 66 from species # 1, with a fitness of -200.0, from the population
# Removed Genome # 65 from species # 1, with a fitness of -200.0, from the population
# Removed Genome # 64 from species # 1, with a fitness of -200.0, from the population
# Removed Genome # 63 from species # 1, with a fitness of -200.0, from the population
# Removed Genome # 62 from species # 1, with a fitness of -200.0, from the population
# Removed Genome # 61 from species # 1, with a fitness of -200.0, from the population
# Removed Genome # 60 from species # 1, with a fitness of -200.0, from the population
# Removed Genome # 59 from species # 1, with a fitness of -200.0, from the population
# Removed Genome # 58 from species # 1, with a fitness of -200.0, from the population
# Removed Genome # 57 from species # 1, with a fitness of -200.0, from the population
# Removed Genome # 56 from species # 1, with a fitness of -200.0, from the population
# Removed Genome # 55 from species # 1, with a fitness of -200.0, from the population
# Removed Genome # 54 from species # 1, with a fitness of -200.0, from the population
# Removed Genome # 53 from species # 1, with a fitness of -200.0, from the population
# Removed Genome # 52 from species # 1, with a fitness of -200.0, from the population
# Removed Genome # 51 from species # 1, with a fitness of -200.0, from the population
# Removed Genome # 50 from species # 1, with a fitness of -200.0, from the population
# Removed Genome # 49 from species # 1, with a fitness of -200.0, from the population
# Removed Genome # 48 from species # 1, with a fitness of -200.0, from the population
# Removed Genome # 47 from species # 1, with a fitness of -200.0, from the population
# Removed Genome # 46 from species # 1, with a fitness of -200.0, from the population
# Removed Genome # 45 from species # 1, with a fitness of -200.0, from the population
# Removed Genome # 44 from species # 1, with a fitness of -200.0, from the population
# Removed Genome # 43 from species # 1, with a fitness of -200.0, from the population
# Removed Genome # 42 from species # 1, with a fitness of -200.0, from the population
# Removed Genome # 41 from species # 1, with a fitness of -200.0, from the population
# Removed Genome # 40 from species # 1, with a fitness of -200.0, from the population
# Removed Genome # 39 from species # 1, with a fitness of -200.0, from the population
# species 1 is allowed to have 149 offspring
# making offspring #2
# Chose crossover
# making offspring #3
# Chose crossover
# making offspring #4
# Chose crossover
# making offspring #5
# Chose crossover
# trying to add new connection
# Attempted to connect too many times. probably already full
# making offspring #6
# Chose no crossover
# making offspring #7
# Chose no crossover
# mutation genome connections !
# making offspring #8
# Chose crossover
# trying to add new connection
# Attempted to connect too many times. probably already full
# making offspring #9
# Chose no crossover
# mutation genome connections !
# trying to add new connection
# Attempted to connect too many times. probably already full
# making offspring #10
# Chose crossover
# trying to add new node
# added hidden node
# trying to add new connection
# making offspring #11
# Chose no crossover
# making offspring #12
# Chose crossover
# trying to add new node
# added hidden node
# trying to add new connection
# making offspring #13
# Chose no crossover
# making offspring #14
# Chose crossover
# trying to add new node
# added hidden node
# making offspring #15
# Chose crossover
# making offspring #16
# Chose crossover
# trying to add new node
# added hidden node
# making offspring #17
# Chose crossover
# trying to add new node
# added hidden node
# making offspring #18
# Chose no crossover
# trying to add new connection
# Attempted to connect too many times. probably already full
# making offspring #19
# Chose crossover
# mutation genome connections !
# trying to add new node
# added hidden node
# making offspring #20
# Chose crossover
# mutation genome connections !
# trying to add new connection
# Attempted to connect too many times. probably already full
# making offspring #21
# Chose crossover
# trying to add new node
# added hidden node
# making offspring #22
# Chose crossover
# trying to add new node
# added hidden node
# making offspring #23
# Chose no crossover
# trying to add new node
# added hidden node
# making offspring #24
# Chose no crossover
# trying to add new node
# added hidden node
# trying to add new connection
# making offspring #25
# Chose crossover
# making offspring #26
# Chose no crossover
# making offspring #27
# Chose crossover
# trying to add new node
# added hidden node
# making offspring #28
# Chose crossover
# making offspring #29
# Chose crossover
# trying to add new node
# added hidden node
# trying to add new connection
# making offspring #30
# Chose crossover
# making offspring #31
# Chose no crossover
# mutation genome connections !
# making offspring #32
# Chose no crossover
# mutation genome connections !
# trying to add new node
# added hidden node
# trying to add new connection
# making offspring #33
# Chose no crossover
# trying to add new node
# added hidden node
# making offspring #34
# Chose crossover
# mutation genome connections !
# trying to add new node
# added hidden node
# making offspring #35
# Chose crossover
# mutation genome connections !
# trying to add new connection
# Attempted to connect too many times. probably already full
# making offspring #36
# Chose crossover
# mutation genome connections !
# trying to add new node
# added hidden node
# trying to add new connection
# making offspring #37
# Chose crossover
# making offspring #38
# Chose crossover
# making offspring #39
# Chose crossover
# trying to add new connection
# Attempted to connect too many times. probably already full
# making offspring #40
# Chose crossover
# trying to add new connection
# Attempted to connect too many times. probably already full
# making offspring #41
# Chose crossover
# trying to add new node
# added hidden node
# making offspring #42
# Chose crossover
# trying to add new connection
# Attempted to connect too many times. probably already full
# making offspring #43
# Chose crossover
# making offspring #44
# Chose crossover
# trying to add new node
# added hidden node
# trying to add new connection
# making offspring #45
# Chose crossover
# trying to add new node
# added hidden node
# trying to add new connection
# making offspring #46
# Chose no crossover
# mutation genome connections !
# making offspring #47
# Chose crossover
# trying to add new node
# added hidden node
# making offspring #48
# Chose crossover
# making offspring #49
# Chose crossover
# making offspring #50
# Chose crossover
# making offspring #51
# Chose crossover
# making offspring #52
# Chose crossover
# making offspring #53
# Chose crossover
# making offspring #54
# Chose crossover
# making offspring #55
# Chose crossover
# making offspring #56
# Chose crossover
# making offspring #57
# Chose no crossover
# making offspring #58
# Chose no crossover
# making offspring #59
# Chose crossover
# mutation genome connections !
# trying to add new connection
# Attempted to connect too many times. probably already full
# making offspring #60
# Chose no crossover
# trying to add new node
# added hidden node
# making offspring #61
# Chose no crossover
# making offspring #62
# Chose crossover
# mutation genome connections !
# trying to add new node
# added hidden node
# trying to add new connection
# making offspring #63
# Chose crossover
# making offspring #64
# Chose crossover
# making offspring #65
# Chose crossover
# mutation genome connections !
# making offspring #66
# Chose crossover
# mutation genome connections !
# trying to add new node
# added hidden node
# making offspring #67
# Chose no crossover
# trying to add new node
# added hidden node
# making offspring #68
# Chose crossover
# mutation genome connections !
# making offspring #69
# Chose crossover
# trying to add new node
# added hidden node
# making offspring #70
# Chose no crossover
# making offspring #71
# Chose crossover
# trying to add new connection
# Attempted to connect too many times. probably already full
# making offspring #72
# Chose crossover
# making offspring #73
# Chose crossover
# trying to add new node
# added hidden node
# making offspring #74
# Chose crossover
# making offspring #75
# Chose crossover
# trying to add new connection
# Attempted to connect too many times. probably already full
# making offspring #76
# Chose crossover
# making offspring #77
# Chose crossover
# making offspring #78
# Chose crossover
# mutation genome connections !
# trying to add new connection
# Attempted to connect too many times. probably already full
# making offspring #79
# Chose crossover
# making offspring #80
# Chose crossover
# trying to add new node
# added hidden node
# making offspring #81
# Chose no crossover
# trying to add new node
# added hidden node
# making offspring #82
# Chose crossover
# trying to add new node
# added hidden node
# making offspring #83
# Chose crossover
# mutation genome connections !
# trying to add new node
# added hidden node
# making offspring #84
# Chose crossover
# trying to add new connection
# Attempted to connect too many times. probably already full
# making offspring #85
# Chose no crossover
# trying to add new connection
# Attempted to connect too many times. probably already full
# making offspring #86
# Chose crossover
# making offspring #87
# Chose crossover
# trying to add new node
# added hidden node
# trying to add new connection
# making offspring #88
# Chose crossover
# mutation genome connections !
# trying to add new connection
# Attempted to connect too many times. probably already full
# making offspring #89
# Chose no crossover
# trying to add new node
# added hidden node
# trying to add new connection
# making offspring #90
# Chose crossover
# trying to add new node
# added hidden node
# making offspring #91
# Chose crossover
# making offspring #92
# Chose no crossover
# trying to add new node
# added hidden node
# trying to add new connection
# making offspring #93
# Chose crossover
# making offspring #94
# Chose no crossover
# mutation genome connections !
# making offspring #95
# Chose crossover
# mutation genome connections !
# trying to add new node
# added hidden node
# making offspring #96
# Chose crossover
# trying to add new connection
# Attempted to connect too many times. probably already full
# making offspring #97
# Chose crossover
# making offspring #98
# Chose no crossover
# mutation genome connections !
# trying to add new node
# added hidden node
# trying to add new connection
# making offspring #99
# Chose crossover
# making offspring #100
# Chose crossover
# trying to add new connection
# Attempted to connect too many times. probably already full
# making offspring #101
# Chose crossover
# mutation genome connections !
# making offspring #102
# Chose crossover
# trying to add new connection
# Attempted to connect too many times. probably already full
# making offspring #103
# Chose crossover
# trying to add new connection
# Attempted to connect too many times. probably already full
# making offspring #104
# Chose crossover
# trying to add new node
# added hidden node
# making offspring #105
# Chose crossover
# making offspring #106
# Chose crossover
# mutation genome connections !
# trying to add new node
# added hidden node
# trying to add new connection
# making offspring #107
# Chose crossover
# trying to add new connection
# Attempted to connect too many times. probably already full
# making offspring #108
# Chose crossover
# trying to add new node
# added hidden node
# trying to add new connection
# making offspring #109
# Chose crossover
# making offspring #110
# Chose crossover
# trying to add new node
# added hidden node
# trying to add new connection
# making offspring #111
# Chose no crossover
# trying to add new node
# added hidden node
# trying to add new connection
# making offspring #112
# Chose crossover
# trying to add new node
# added hidden node
# trying to add new connection
# making offspring #113
# Chose crossover
# making offspring #114
# Chose no crossover
# making offspring #115
# Chose crossover
# mutation genome connections !
# making offspring #116
# Chose crossover
# trying to add new node
# added hidden node
# making offspring #117
# Chose crossover
# trying to add new node
# added hidden node
# trying to add new connection
# making offspring #118
# Chose crossover
# trying to add new node
# added hidden node
# making offspring #119
# Chose crossover
# trying to add new connection
# Attempted to connect too many times. probably already full
# making offspring #120
# Chose crossover
# mutation genome connections !
# making offspring #121
# Chose crossover
# making offspring #122
# Chose crossover
# trying to add new node
# added hidden node
# trying to add new connection
# making offspring #123
# Chose crossover
# making offspring #124
# Chose crossover
# making offspring #125
# Chose crossover
# trying to add new node
# added hidden node
# trying to add new connection
# making offspring #126
# Chose crossover
# making offspring #127
# Chose no crossover
# trying to add new node
# added hidden node
# making offspring #128
# Chose crossover
# mutation genome connections !
# trying to add new node
# added hidden node
# trying to add new connection
# making offspring #129
# Chose no crossover
# mutation genome connections !
# trying to add new connection
# Attempted to connect too many times. probably already full
# making offspring #130
# Chose crossover
# trying to add new node
# added hidden node
# making offspring #131
# Chose crossover
# trying to add new node
# added hidden node
# making offspring #132
# Chose crossover
# trying to add new node
# added hidden node
# making offspring #133
# Chose crossover
# trying to add new node
# added hidden node
# trying to add new connection
# making offspring #134
# Chose crossover
# mutation genome connections !
# trying to add new node
# added hidden node
# trying to add new connection
# making offspring #135
# Chose crossover
# mutation genome connections !
# making offspring #136
# Chose crossover
# trying to add new node
# added hidden node
# making offspring #137
# Chose crossover
# trying to add new node
# added hidden node
# making offspring #138
# Chose crossover
# mutation genome connections !
# making offspring #139
# Chose crossover
# trying to add new node
# added hidden node
# making offspring #140
# Chose no crossover
# trying to add new node
# added hidden node
# making offspring #141
# Chose crossover
# mutation genome connections !
# trying to add new node
# added hidden node
# making offspring #142
# Chose crossover
# mutation genome connections !
# trying to add new connection
# Attempted to connect too many times. probably already full
# making offspring #143
# Chose crossover
# mutation genome connections !
# making offspring #144
# Chose crossover
# trying to add new node
# added hidden node
# making offspring #145
# Chose crossover
# making offspring #146
# Chose crossover
# trying to add new node
# added hidden node
# making offspring #147
# Chose no crossover
# mutation genome connections !
# trying to add new node
# added hidden node
# trying to add new connection
# making offspring #148
# Chose no crossover
# mutation genome connections !
# trying to add new node
# added hidden node
# making offspring #149
# Chose crossover
# mutation genome connections !
# trying to add new node
# added hidden node
# trying to add new connection
# making offspring #150
# Chose crossover
# Final value of i: 150
# Beginning Generation #2
# Beginning evaluation on genome #1
# 0.22788308131907528
# inserting into species#1
# Episode finished after 201 timesteps
# Genome fitness: -200.0
# Beginning evaluation on genome #2
# 0.2671060301020469
# inserting into species#1
# Episode finished after 201 timesteps
# Genome fitness: -200.0
# Beginning evaluation on genome #3
# 0.23102128152448742
# inserting into species#1
# Episode finished after 201 timesteps
# Genome fitness: -200.0
# Beginning evaluation on genome #4
# 0.255027347574382
# inserting into species#1
# Episode finished after 201 timesteps
# Genome fitness: -200.0
# Beginning evaluation on genome #5
# 0.2252633123821367
# inserting into species#1
# Episode finished after 201 timesteps
# Genome fitness: -200.0
# Beginning evaluation on genome #6
# 0.2686587296758729
# inserting into species#1
# Episode finished after 201 timesteps
# Genome fitness: -200.0
# Beginning evaluation on genome #7
# 0.3270452835919231
# inserting into species#1
# Episode finished after 201 timesteps
# Genome fitness: -200.0
# Beginning evaluation on genome #8
# 0.35178916466402804
# inserting into species#1
# Episode finished after 201 timesteps
# Genome fitness: -200.0
# Beginning evaluation on genome #9
# 0.22788308131907528
# inserting into species#1
# Episode finished after 201 timesteps
# Genome fitness: -200.0
# Beginning evaluation on genome #10
# 1.2444276707296988
# creating new species:2
# 2
# Episode finished after 201 timesteps
# Genome fitness: -200.0
# Beginning evaluation on genome #11
# 0.4061828694558498
# inserting into species#1
# Episode finished after 201 timesteps
# Genome fitness: -200.0
# Beginning evaluation on genome #12
# 1.2184918616677045
# 1.609055696141542
# creating new species:3
# 3
# Episode finished after 201 timesteps
# Genome fitness: -200.0
# Beginning evaluation on genome #13
# 0.0
# inserting into species#1
# Episode finished after 201 timesteps
# Genome fitness: -200.0
# Beginning evaluation on genome #14
# 0.9416098676577279
# inserting into species#1
# Episode finished after 201 timesteps
# Genome fitness: -200.0
# Beginning evaluation on genome #15
# 0.18921501249377726
# inserting into species#1
# Episode finished after 201 timesteps
# Genome fitness: -200.0
# Beginning evaluation on genome #16
# 0.952536039654864
# inserting into species#1
# Episode finished after 201 timesteps
# Genome fitness: -200.0
# Beginning evaluation on genome #17
# 0.9284869301198129
# inserting into species#1
# Episode finished after 201 timesteps
# Genome fitness: -200.0
# Beginning evaluation on genome #18
# 0.2686587296758729
# inserting into species#1
# Episode finished after 201 timesteps
# Genome fitness: -200.0
# Beginning evaluation on genome #19
# 1.1205168346277252
# 1.2368223717777642
# 1.9679866162398425
# creating new species:4
# 4
# Episode finished after 201 timesteps
# Genome fitness: -200.0
# Beginning evaluation on genome #20
# 0.1548668474103017
# inserting into species#1
# Episode finished after 201 timesteps
# Genome fitness: -200.0
# Beginning evaluation on genome #21
# 0.926659293696
# inserting into species#1
# Episode finished after 201 timesteps
# Genome fitness: -200.0
# Beginning evaluation on genome #22
# 1.0790618919367554
# 0.5275034807791342
# inserting into species#2
# Episode finished after 201 timesteps
# Genome fitness: -200.0
# Beginning evaluation on genome #23
# 1.0200015797777124
# 1.9555072681992343
# 1.1283100411585856
# 1.0780325687448022
# creating new species:5
# 5
# Episode finished after 201 timesteps
# Genome fitness: -200.0
# Beginning evaluation on genome #24
# 1.1653629141354815
# 1.4829617399529613
# 0.9518898308446484
# inserting into species#3
# Episode finished after 201 timesteps
# Genome fitness: -200.0
# Beginning evaluation on genome #25
# 0.2280775203079359
# inserting into species#1
# Episode finished after 201 timesteps
# Genome fitness: -200.0
# Beginning evaluation on genome #26
# 0.0
# inserting into species#1
# Episode finished after 201 timesteps
# Genome fitness: -200.0
# Beginning evaluation on genome #27
# 0.8926356414082087
# inserting into species#1
# Episode finished after 201 timesteps
# Genome fitness: -200.0
# Beginning evaluation on genome #28
# 0.32744100709315777
# inserting into species#1
# Episode finished after 201 timesteps
# Genome fitness: -200.0
# Beginning evaluation on genome #29
# 1.3799505759662725
# 1.5748270665964876
# 1.674768165590451
# 1.230265954755759
# 1.2644277442167804
# creating new species:6
# 6
# Episode finished after 201 timesteps
# Genome fitness: -200.0
# Beginning evaluation on genome #30
# 0.32443996044176354
# inserting into species#1
# Episode finished after 201 timesteps
# Genome fitness: -200.0
# Beginning evaluation on genome #31
# 0.19290386837710105
# inserting into species#1
# Episode finished after 201 timesteps
# Genome fitness: -200.0
# Beginning evaluation on genome #32
# 1.3697216211393337
# 1.6070920036480465
# 0.9686086994488192
# inserting into species#3
# Episode finished after 201 timesteps
# Genome fitness: -200.0
# Beginning evaluation on genome #33
# 0.926659293696
# inserting into species#1
# Episode finished after 201 timesteps
# Genome fitness: -200.0
# Beginning evaluation on genome #34
# 1.133122079320498
# 1.2267062761982674
# 1.3275432904105564
# 1.7807051406175498
# 1.7054012576384698
# 0.614054217900057
# ...
# Removed Genome # 75 from species # 5, with a fitness of -200.0, from the population
# Removed Genome # 74 from species # 1, with a fitness of -200.0, from the population
# Removed Genome # 73 from species # 1, with a fitness of -200.0, from the population
# Removed Genome # 72 from species # 1, with a fitness of -200.0, from the population
# Removed Genome # 71 from species # 4, with a fitness of -200.0, from the population
# Removed Genome # 70 from species # 4, with a fitness of -200.0, from the population
# Removed Genome # 69 from species # 1, with a fitness of -200.0, from the population
# Removed Genome # 68 from species # 4, with a fitness of -200.0, from the population
# Removed Genome # 67 from species # 4, with a fitness of -200.0, from the population
# Removed Genome # 66 from species # 4, with a fitness of -200.0, from the population
# Removed Genome # 65 from species # 1, with a fitness of -200.0, from the population
# Removed Genome # 64 from species # 1, with a fitness of -200.0, from the population
# Removed Genome # 63 from species # 1, with a fitness of -200.0, from the population
# Removed Genome # 62 from species # 1, with a fitness of -200.0, from the population
# Removed Genome # 61 from species # 4, with a fitness of -200.0, from the population
# Removed Genome # 60 from species # 1, with a fitness of -200.0, from the population
# Removed Genome # 59 from species # 1, with a fitness of -200.0, from the population
# Removed Genome # 58 from species # 2, with a fitness of -200.0, from the population
# Removed Genome # 57 from species # 1, with a fitness of -200.0, from the population
# Removed Genome # 56 from species # 1, with a fitness of -200.0, from the population
# Removed Genome # 55 from species # 1, with a fitness of -200.0, from the population
# Removed Genome # 54 from species # 1, with a fitness of -200.0, from the population
# Removed Genome # 53 from species # 1, with a fitness of -200.0, from the population
# Removed Genome # 52 from species # 1, with a fitness of -200.0, from the population
# Removed Genome # 51 from species # 1, with a fitness of -200.0, from the population
# Removed Genome # 50 from species # 3, with a fitness of -200.0, from the population
# Removed Genome # 49 from species # 4, with a fitness of -200.0, from the population
# Removed Genome # 48 from species # 1, with a fitness of -200.0, from the population
# Removed Genome # 47 from species # 1, with a fitness of -200.0, from the population
# Removed Genome # 46 from species # 4, with a fitness of -200.0, from the population
# Removed Genome # 45 from species # 2, with a fitness of -200.0, from the population
# Removed Genome # 44 from species # 1, with a fitness of -200.0, from the population
# Removed Genome # 43 from species # 6, with a fitness of -200.0, from the population
# Removed Genome # 42 from species # 3, with a fitness of -200.0, from the population
# Removed Genome # 41 from species # 3, with a fitness of -200.0, from the population
# Removed Genome # 40 from species # 1, with a fitness of -200.0, from the population
# Removed Genome # 39 from species # 2, with a fitness of -200.0, from the population
# species 1 is allowed to have 85 offspring
# making offspring #5
# Chose crossover
# trying to add new node
# added hidden node
# making offspring #6
# Chose crossover
# making offspring #7
# Chose no crossover
# trying to add new node
# added hidden node
# making offspring #8
# Chose crossover
# mutation genome connections !
# trying to add new node
# added hidden node
# making offspring #9
# Chose crossover
# making offspring #10
# Chose no crossover
# making offspring #11
# Chose crossover
# making offspring #12
# Chose crossover
# trying to add new node
# added hidden node
# making offspring #13
# Chose no crossover
# mutation genome connections !
# making offspring #14
# Chose no crossover
# trying to add new node
# added hidden node
# trying to add new connection
# making offspring #15
# Chose crossover
# making offspring #16
# Chose crossover
# mutation genome connections !
# trying to add new node
# added hidden node
# making offspring #17
# Chose no crossover
# trying to add new node
# added hidden node
# trying to add new connection
# making offspring #18
# Chose no crossover
# mutation genome connections !
# making offspring #19
# Chose crossover
# trying to add new node
# added hidden node
# making offspring #20
# Chose crossover
# trying to add new node
# added hidden node
# making offspring #21
# Chose crossover
# mutation genome connections !
# making offspring #22
# Chose crossover
# mutation genome connections !
# trying to add new node
# added hidden node
# making offspring #23
# Chose crossover
# trying to add new node
# added hidden node
# making offspring #24
# Chose no crossover
# mutation genome connections !
# trying to add new node
# added hidden node
# making offspring #25
# Chose crossover
# trying to add new node
# added hidden node
# trying to add new connection
# making offspring #26
# Chose crossover
# making offspring #27
# Chose no crossover
# making offspring #28
# Chose crossover
# trying to add new connection
# Attempted to connect too many times. probably already full
# making offspring #29
# Chose crossover
# mutation genome connections !
# trying to add new connection
# Attempted to connect too many times. probably already full
# making offspring #30
# Chose crossover
# making offspring #31
# Chose no crossover
# trying to add new node
# added hidden node
# making offspring #32
# Chose no crossover
# trying to add new connection
# making offspring #33
# Chose crossover
# trying to add new node
# added hidden node
# making offspring #34
# Chose crossover
# trying to add new connection
# Attempted to connect too many times. probably already full
# making offspring #35
# Chose crossover
# trying to add new node
# added hidden node
# trying to add new connection
# making offspring #36
# Chose crossover
# trying to add new node
# added hidden node
# making offspring #37
# Chose crossover
# trying to add new node
# added hidden node
# making offspring #38
# Chose crossover
# trying to add new node
# added hidden node
# making offspring #39
# Chose crossover
# making offspring #40
# Chose crossover
# trying to add new connection
# Attempted to connect too many times. probably already full
# making offspring #41
# Chose crossover
# mutation genome connections !
# trying to add new node
# added hidden node
# making offspring #42
# Chose no crossover
# making offspring #43
# Chose no crossover
# making offspring #44
# Chose crossover
# making offspring #45
# Chose no crossover
# mutation genome connections !
# trying to add new connection
# Attempted to connect too many times. probably already full
# making offspring #46
# Chose crossover
# trying to add new node
# added hidden node
# making offspring #47
# Chose crossover
# mutation genome connections !
# making offspring #48
# Chose crossover
# mutation genome connections !
# trying to add new node
# added hidden node
# making offspring #49
# Chose crossover
# making offspring #50
# Chose crossover
# mutation genome connections !
# trying to add new node
# added hidden node
# making offspring #51
# Chose crossover
# trying to add new connection
# Attempted to connect too many times. probably already full
# making offspring #52
# Chose crossover
# trying to add new node
# added hidden node
# trying to add new connection
# making offspring #53
# Chose crossover
# mutation genome connections !
# trying to add new node
# added hidden node
# trying to add new connection
# making offspring #54
# Chose crossover
# making offspring #55
# Chose crossover
# making offspring #56
# Chose crossover
# mutation genome connections !
# making offspring #57
# Chose crossover
# trying to add new node
# added hidden node
# making offspring #58
# Chose crossover
# making offspring #59
# Chose no crossover
# trying to add new node
# added hidden node
# making offspring #60
# Chose crossover
# making offspring #61
# Chose crossover
# mutation genome connections !
# trying to add new node
# added hidden node
# making offspring #62
# Chose no crossover
# trying to add new node
# added hidden node
# making offspring #63
# Chose crossover
# trying to add new node
# added hidden node
# making offspring #64
# Chose crossover
# trying to add new node
# added hidden node
# making offspring #65
# Chose no crossover
# mutation genome connections !
# trying to add new node
# added hidden node
# making offspring #66
# Chose crossover
# trying to add new node
# added hidden node
# making offspring #67
# Chose crossover
# trying to add new node
# added hidden node
# making offspring #68
# Chose crossover
# trying to add new node
# added hidden node
# making offspring #69
# Chose no crossover
# making offspring #70
# Chose no crossover
# making offspring #71
# Chose no crossover
# making offspring #72
# Chose crossover
# trying to add new node
# added hidden node
# making offspring #73
# Chose crossover
# mutation genome connections !
# trying to add new node
# added hidden node
# trying to add new connection
# making offspring #74
# Chose no crossover
# mutation genome connections !
# making offspring #75
# Chose no crossover
# trying to add new connection
# Attempted to connect too many times. probably already full
# making offspring #76
# Chose crossover
# mutation genome connections !
# making offspring #77
# Chose no crossover
# trying to add new node
# added hidden node
# making offspring #78
# Chose no crossover
# making offspring #79
# Chose crossover
# trying to add new node
# added hidden node
# making offspring #80
# Chose crossover
# trying to add new connection
# Attempted to connect too many times. probably already full
# making offspring #81
# Chose crossover
# trying to add new connection
# Attempted to connect too many times. probably already full
# making offspring #82
# Chose crossover
# mutation genome connections !
# trying to add new node
# added hidden node
# trying to add new connection
# making offspring #83
# Chose crossover
# making offspring #84
# Chose no crossover
# making offspring #85
# Chose crossover
# trying to add new connection
# Attempted to connect too many times. probably already full
# making offspring #86
# Chose crossover
# making offspring #87
# Chose no crossover
# making offspring #88
# Chose crossover
# trying to add new connection
# Attempted to connect too many times. probably already full
# making offspring #89
# Chose crossover
# species 2 is allowed to have 12 offspring
# making offspring #90
# Chose crossover
# mutation genome connections !
# trying to add new node
# added hidden node
# making offspring #91
# Chose crossover
# mutation genome connections !
# making offspring #92
# Chose crossover
# mutation genome connections !
# making offspring #93
# Chose no crossover
# trying to add new node
# added hidden node
# trying to add new connection
# making offspring #94
# Chose crossover
# trying to add new node
# added hidden node
# making offspring #95
# Chose no crossover
# trying to add new node
# added hidden node
# making offspring #96
# Chose no crossover
# trying to add new node
# added hidden node
# making offspring #97
# Chose no crossover
# trying to add new connection
# making offspring #98
# Chose crossover
# trying to add new connection
# Attempted to connect too many times. probably already full
# making offspring #99
# Chose crossover
# trying to add new node
# added hidden node
# making offspring #100
# Chose crossover
# trying to add new node
# added hidden node
# making offspring #101
# Chose no crossover
# trying to add new connection
# species 3 is allowed to have 13 offspring
# making offspring #102
# Chose no crossover
# making offspring #103
# Chose no crossover
# making offspring #104
# Chose crossover
# trying to add new connection
# Attempted to connect too many times. probably already full
# making offspring #105
# Chose crossover
# mutation genome connections !
# trying to add new connection
# Attempted to connect too many times. probably already full
# making offspring #106
# Chose no crossover
# making offspring #107
# Chose crossover
# making offspring #108
# Chose no crossover
# making offspring #109
# Chose crossover
# making offspring #110
# Chose crossover
# trying to add new node
# added hidden node
# trying to add new connection
# making offspring #111
# Chose crossover
# trying to add new node
# added hidden node
# making offspring #112
# Chose crossover
# making offspring #113
# Chose crossover
# trying to add new connection
# Attempted to connect too many times. probably already full
# making offspring #114
# Chose crossover
# trying to add new node
# added hidden node
# trying to add new connection
# species 4 is allowed to have 17 offspring
# making offspring #115
# Chose crossover
# trying to add new connection
# Attempted to connect too many times. probably already full
# making offspring #116
# Chose no crossover
# trying to add new connection
# making offspring #117
# Chose crossover
# mutation genome connections !
# making offspring #118
# Chose crossover
# making offspring #119
# Chose no crossover
# trying to add new connection
# making offspring #120
# Chose crossover
# mutation genome connections !
# trying to add new node
# added hidden node
# trying to add new connection
# making offspring #121
# Chose crossover
# trying to add new node
# added hidden node
# making offspring #122
# Chose crossover
# trying to add new node
# added hidden node
# making offspring #123
# Chose no crossover
# making offspring #124
# Chose crossover
# trying to add new node
# added hidden node
# trying to add new connection
# making offspring #125
# Chose crossover
# mutation genome connections !
# making offspring #126
# Chose crossover
# making offspring #127
# Chose no crossover
# mutation genome connections !
# making offspring #128
# Chose crossover
# mutation genome connections !
# trying to add new node
# added hidden node
# making offspring #129
# Chose crossover
# trying to add new node
# added hidden node
# making offspring #130
# Chose no crossover
# mutation genome connections !
# making offspring #131
# Chose crossover
# trying to add new node
# added hidden node
# species 5 is allowed to have 3 offspring
# making offspring #132
# Chose no crossover
# trying to add new connection
# making offspring #133
# Chose no crossover
# mutation genome connections !
# trying to add new connection
# making offspring #134
# Chose no crossover
# trying to add new node
# added hidden node
# trying to add new connection
# species 6 is allowed to have 3 offspring
# making offspring #135
# Chose no crossover
# making offspring #136
# Chose no crossover
# making offspring #137
# Chose no crossover
# species 7 is allowed to have 0 offspring
# could not breed species8, list is empty !
# could not breed species9, list is empty !
# could not breed species10, list is empty !
# could not breed species11, list is empty !
# could not breed species12, list is empty !
# could not breed species13, list is empty !
# now for the leftovers:
# random species mating
# species does not have enough to breed. skipping.
# random species mating
# Chose no crossover
# trying to add new connection
# random species mating
# species does not have enough to breed. skipping.
# random species mating
# Chose no crossover
# random species mating
# Chose no crossover
# trying to add new connection
# random species mating
# species does not have enough to breed. skipping.
# random species mating
# Chose no crossover
# random species mating
# Chose no crossover
# mutation genome connections !
# trying to add new connection
# random species mating
# species does not have enough to breed. skipping.
# random species mating
# Chose crossover
# random species mating
# Chose crossover
# Final value of i: 144
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-20-9d6e6376711f> in <module>
#     317         if (generation >= 0):
#     318             for s in species:
# --> 319                 species[s] = {'summedSharedFitness': 0.0, 'maxFitness': 0.0, 'maxAdjustedFitness': 0.0, 'stagnantCounter': species[s]['stagnantCounter']+1, 'isStagnant': False, 'list' : [random.choice(species[s]['list'])]}
#     320                 species[s]['bestGenome'] = species[s]['list'][0]
#     321                 if species[s]['stagnantCounter'] >= numUntilStagnant:  # if the maximum fitness of a species did not improve in 15 generations, the networks in the stagnant species were not allowed to reproduce
#
# C:\Users\valen\anaconda3\lib\random.py in choice(self, seq)
#     259             i = self._randbelow(len(seq))
#     260         except ValueError:
# --> 261             raise IndexError('Cannot choose from an empty sequence') from None
#     262         return seq[i]
#     263
#
# IndexError: Cannot choose from an empty sequence

# %%
# load the networks that solved the problem !
with open('data/bestGenome_cartpole.dictionary', 'rb') as dictionary_file:
    bestGenomeDictionary = pickle.load(dictionary_file)

# %%
# test bench 

env = gym.make(envName)

testBenchTotalFitness = 0

for i in range(100):
    t = 0
    bestGenome.resetFitness()
    observation = env.reset()
    while(True):
        t+=1
        env.render()
        action = bestGenome.evaluateAction(observation)
        observation, reward, done, info = env.step(action)
        bestGenome.fitness += reward
        if done:
            print("Episode finished after {} timesteps".format(t+1))
            testBenchTotalFitness+=bestGenome.fitness
            print("Genome fitness: {}".format(bestGenome.fitness))
            break

print('average fitness across 100 trials:{}'.format(testBenchTotalFitness/100))
env.close()
